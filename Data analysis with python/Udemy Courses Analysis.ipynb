# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
courses = pd.read_csv(r"C:\Users\antho\OneDrive\Υπολογιστής\Ανθούλα\projects\python\Data Analysis with Python\Udemy Courses.csv")

# %%
courses.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments
# 1           1 hour  2017-04-12T19:06:34Z  Musical Instruments
# 2        1.5 hours  2017-04-26T18:34:57Z  Musical Instruments
# 3           1 hour  2017-02-21T23:48:18Z  Musical Instruments
# 4          37 mins  2017-02-21T23:44:49Z  Musical Instruments

# %%
#delete duplicate rows
courses.drop_duplicates(inplace = True)
courses.drop_duplicates(subset = 'course_title', keep = 'first', inplace = True)

# %%
courses.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
#number of courses of each subject category
courses.subject.value_counts(ascending = True)
# Out:
# Graphic Design          600
# Musical Instruments     676
# Business Finance       1195
# Web Development        1196
# Name: subject, dtype: int64

# %%
#number of courses according to subject and level
courses.groupby(['subject', 'level']).size()
# Out:
# subject              level
# Business Finance     All Levels            696
#                      Beginner Level        340
#                      Expert Level           31
#                      Intermediate Level    128
# Graphic Design       All Levels            298
#                      Beginner Level        241
#                      Expert Level            5
#                      Intermediate Level     56
# Musical Instruments  All Levels            276
#                      Beginner Level        294
#                      Expert Level            7
#                      Intermediate Level     99
# Web Development      All Levels            657
#                      Beginner Level        389
#                      Expert Level           15
#                      Intermediate Level    135
# dtype: int64

# %%
courses.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
#replace 'Free' values in price column
courses['price'].replace({'Free': '0'}, inplace = True)
#change the data type of price column to numeric
courses['price'] = pd.to_numeric(courses['price'])
courses.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                   int64
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
#min price of each subject category
courses.groupby('subject').price.min()
# Out:
# subject
# Business Finance       0
# Graphic Design         0
# Musical Instruments    0
# Web Development        0
# Name: price, dtype: int64

# %%
#max price of each subject category
courses.groupby('subject').price.max()
# Out:
# subject
# Business Finance       200
# Graphic Design         200
# Musical Instruments    200
# Web Development        200
# Name: price, dtype: int64

# %%
#mean price of each subject category
courses.groupby('subject').price.mean()
# Out:
# subject
# Business Finance       68.564854
# Graphic Design         58.016667
# Musical Instruments    49.341716
# Web Development        77.169732
# Name: price, dtype: float64

# %%
courses['is_paid'].value_counts().plot(kind = 'pie', autopct='%1.0f%%')
plt.title('Percentage of free/paid courses')
plt.ylabel('')
plt.show()

# %%
#number of subscribers according to whether the course is free of cost or not
courses.groupby('is_paid').num_subscribers.sum()
# Out:
# is_paid
# False    3573088
# True     8132569
# Name: num_subscribers, dtype: int64

# %%
#top 5 courses according to the number of subscribers
courses.nlargest(5, ['num_subscribers'])
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
#
#       price  num_subscribers  num_reviews  num_lectures           level  \
# 2230      0           268923         8629            45      All Levels
# 776       0           161029          279            27  Beginner Level
# 3385    200           121584        27445           342      All Levels
# 640       0           120291         5924            30  Beginner Level
# 3316    200           114512        22412           304      All Levels
#
#      content_duration   published_timestamp          subject
# 2230       10.5 hours  2013-02-14T07:03:41Z  Web Development
# 776         3.5 hours  2013-06-09T15:51:55Z  Web Development
# 3385         43 hours  2015-11-02T21:13:27Z  Web Development
# 640           3 hours  2014-04-08T16:21:30Z  Web Development
# 3316       30.5 hours  2016-03-08T22:28:36Z  Web Development

# %%
#least 5 courses according to the number of subscribers and price
courses.nsmallest(5, ['num_subscribers', 'price'])
# Out:
#      course_id                                       course_title  is_paid  \
# 37     1234656                              4 Week Rhythm Mastery     True
# 91     1265814  ABRSM Grade III Piano Class - Handel Sonatina ...     True
# 98     1219820  Accounting - The 6 most important rules you mu...     True
# 185     872262                Adobe Photoshop pentru Social Media     True
# 476    1252410  Beginners Guide to Kindle Ebook Covers Design ...     True
#
#      price  num_subscribers  num_reviews  num_lectures           level  \
# 37      20                0            0            28  Beginner Level
# 91      20                0            0             5  Beginner Level
# 98      20                0            0             9      All Levels
# 185     20                0            0            12  Beginner Level
# 476     20                0            0            16      All Levels
#
#     content_duration   published_timestamp              subject
# 37         2.5 hours  2017-07-05T16:07:44Z  Musical Instruments
# 91           31 mins  2017-07-06T16:12:34Z  Musical Instruments
# 98            1 hour  2017-05-25T21:55:50Z     Business Finance
# 185          34 mins  2016-06-08T16:02:39Z       Graphic Design
# 476        1.5 hours  2017-06-19T19:26:46Z       Graphic Design

# %%
#show all the courses that are related with 'sql' and the price is less than or equal to 50
courses[(courses.course_title.str.contains('sql')) & (courses.price <= 50)]
# Out:
#       course_id                                       course_title  is_paid  \
# 618     1201054               Build CRUD Application - PHP & Mysql    False
# 897     1189508  Create a social network using PHP Mysqli HTML ...     True
# 900     1176460              Create Ajax Chat App with PHP & Mysql     True
# 2607    1008246  Modern E-Commerce Store In php & mysqli With B...     True
#
#       price  num_subscribers  num_reviews  num_lectures               level  \
# 618       0             4405           71            12      Beginner Level
# 897      40             1477           17            27  Intermediate Level
# 900      45              540           11            19      Beginner Level
# 2607     50              240           45           358          All Levels
#
#      content_duration   published_timestamp          subject
# 618         1.5 hours  2017-05-04T16:47:24Z  Web Development
# 897           6 hours  2017-04-24T00:18:42Z  Web Development
# 900            1 hour  2017-04-15T00:56:41Z  Web Development
# 2607       66.5 hours  2016-12-09T16:18:49Z  Web Development

# %%
#make and add two new columns of date and time to the dataframe from published_timestamp column
#convert the published_timestamp column into two new columns (published_date and published_time)
courses['published_timestamp'] = pd.to_datetime(courses.published_timestamp)
courses['published_date'] = pd.to_datetime(courses['published_timestamp']).dt.date
courses['published_time'] = pd.to_datetime(courses['published_timestamp']).dt.time
del courses['published_timestamp']

# %%
#courses that published in the first semester of 2016
courses['published_date'] = pd.to_datetime(courses['published_date'])
courses[(courses['published_date'].dt.year == 2016) & ((courses['published_date'].dt.month >= 1) & (courses['published_date'].dt.month <= 6))]
# Out:
#       course_id                                       course_title  is_paid  \
# 7        768028  * An Integrated Approach to the Fundamentals o...     True
# 9        738910  [Value Investing] Where White People Keep Thei...     True
# 22       759972                150 Rock Guitar Licks You MUST Know     True
# 25       638966  188% Profit in 1Year - Forex ALGO Robot Tradin...     True
# 50       665042  8 Beautiful Ruby on Rails Apps in 30 Days & TD...     True
# ...         ...                                                ...      ...
# 3607     722754  WordPress Development Crash Course: From Zero ...     True
# 3608     882488                WordPress Development For Beginners     True
# 3640     774910     WordPress: Create an Amazing Website With Ease     True
# 3651     424864  Write PHP Like a Pro: Build a PHP MVC Framewor...     True
# 3652     752706  Write quicker HTML5 and CSS 3; productivity ha...    False
#
#       price  num_subscribers  num_reviews  num_lectures         level  \
# 7       200              134           14           123    All Levels
# 9       200             2715           70            20  Expert Level
# 22       45              252           14            21    All Levels
# 25      120              357           71            20    All Levels
# 50      100             5962          466           132    All Levels
# ...     ...              ...          ...           ...           ...
# 3607     60             1699            8            22    All Levels
# 3608     95            23572          210            20    All Levels
# 3640    200             1109           13            24    All Levels
# 3651     70             1703          435            65    All Levels
# 3652      0            13016          286            15    All Levels
#
#      content_duration              subject published_date published_time
# 7           5.5 hours     Business Finance     2016-03-15       17:23:07
# 9             4 hours     Business Finance     2016-05-25       21:04:41
# 22          4.5 hours  Musical Instruments     2016-02-19       17:24:14
# 25            2 hours     Business Finance     2016-05-03       19:04:41
# 50           16 hours      Web Development     2016-03-08       07:36:40
# ...               ...                  ...            ...            ...
# 3607          2 hours      Web Development     2016-02-01       22:07:26
# 3608          2 hours      Web Development     2016-06-20       18:46:15
# 3640        2.5 hours      Web Development     2016-05-03       19:53:12
# 3651          3 hours      Web Development     2016-02-04       22:36:17
# 3652        1.5 hours      Web Development     2016-03-03       17:45:31
#
# [631 rows x 12 columns]

# %%
courses.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0     35             3137           18            68          All Levels
# 1     75             1593            1            41  Intermediate Level
# 2     75              482            1            47  Intermediate Level
#
#   content_duration              subject published_date published_time
# 0        1.5 hours  Musical Instruments     2014-09-18       05:07:05
# 1           1 hour  Musical Instruments     2017-04-12       19:06:34
# 2        1.5 hours  Musical Instruments     2017-04-26       18:34:57

# %%
#apply a 20% discount on the price of each course
courses.insert(4, 'discount_price', courses['price'].apply(lambda x:x-0.2*x))
courses.head(3)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
#
#    price  discount_price  num_subscribers  num_reviews  num_lectures  \
# 0     35            28.0             3137           18            68
# 1     75            60.0             1593            1            41
# 2     75            60.0              482            1            47
#
#                 level content_duration              subject published_date  \
# 0          All Levels        1.5 hours  Musical Instruments     2014-09-18
# 1  Intermediate Level           1 hour  Musical Instruments     2017-04-12
# 2  Intermediate Level        1.5 hours  Musical Instruments     2017-04-26
#
#   published_time
# 0       05:07:05
# 1       19:06:34
# 2       18:34:57

# %%
subs_per_year = courses.groupby(courses['published_date'].dt.year).num_subscribers.mean()
subs_per_year.plot(kind = 'bar')
plt.title('Mean subscribers per year')
plt.xlabel('published year')
plt.ylabel('subscribers')
plt.show()

# %%
#looking at correlation

sns.heatmap(courses.corr(), annot = True)
plt.title('Correlation for numeric columns')
plt.show()

# %%
#plot the correlation between num_subscribers and num_reviews

sns.regplot(x = 'num_subscribers', y = 'num_reviews', data = courses, line_kws = {'color' : 'green'})
plt.show()
